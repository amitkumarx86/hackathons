# %%
def show(img):
    import matplotlib.pyplot as plt
    plt.imshow(img, cmap='gray')
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
show(im)

# %%
import cv2
import matplotlib.pyplot as plt

im = cv2.imread("c112.png",0)
# show(im)
h, w = im.shape
date = im[int(h*0.07):int(h*0.125), int(w*0.773):w-(int(h*0.05))]
show(date)
