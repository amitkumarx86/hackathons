# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# im = Image.open("cheque.png")
# rgb_im = im.convert('RGB')
# rgb_im.save('cheque.jpg')

im = cv2.imread('c1.png',0)

# im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)

im = cv2.resize(im, (2708, 1216), interpolation = cv2.INTER_AREA)

# branch information
cv2.rectangle(im,(900,0),(2100,200),(0,0,0),10)
# # date
cv2.rectangle(im,(2100,65),(2650,150),(255,0,0),5)

# # payee
cv2.rectangle(im,(200,170),(2000,330),(0,0,0),10)

# # type of cheque
cv2.rectangle(im,(2390,220),(2650,320),(0,0,0),10)

# # amount in words
cv2.rectangle(im,(100,330),(2630,530),(0,255,0),10)

# # amount in digits
cv2.rectangle(im,(2100,430),(2630,530),(0,0,0),10)

# # account number
cv2.rectangle(im,(200,565),(1100,700),(0,0,0),10)

# # signature 
cv2.rectangle(im,(1850,600),(2700,900),(0,0,0),10)

# # cheque info
cv2.rectangle(im,(710,1090),(1000,1170),(0,0,0),10)

# # type cheque
# cv2.rectangle(im,(0,0),(250,110),(0,0,0),10)

plt.imshow(im)
plt.show()
im.shape
# Out:
# (1216, 2708)

# %%
imgray = im
dateVar = imgray[80:140, 2100:2650]
dateVar = cv2.medianBlur(dateVar,5)
kernel = np.ones((5,5),np.uint8)
dateVar = cv2.erode(dateVar,kernel,iterations = 1)
cv2.imwrite("date.jpg",dateVar)
dateVar = getText("date.jpg")
import re
dateVar = ''.join(re.findall(r'\d+', dateVar))
dateVar = dateVar[0]+""+dateVar[1]+"/"+dateVar[2]+""+dateVar[3]+"/"+dateVar[4]+""+dateVar[5]+""+dateVar[6]+""+dateVar[7]
dateVar
# Out:
# '22/11/2017'

# %%
# show(amntWords2)
amntWords1  = im[325:435,400:2630]
amntWords2  = im[440:535,100:1870]
cv2.imwrite("amntWords1.jpg",amntWords1)
cv2.imwrite("amntWords2.jpg",amntWords2)
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
text1 = pytesseract.image_to_string(Image.open('amntWords1.jpg')).strip()
text2 = pytesseract.image_to_string(Image.open('amntWords2.jpg')).strip()
amntWords = (text1 + " " + text2).strip()
print("amn = "+amntWords)
show(amntWords1)
show(amntWords2)
# Out:
# amn = TEN THOUSAND

# %%
date = im[85:155, 2110:2650]
date1 = date[0:70, 0:55]
show(date1)
date1 = cv2.medianBlur(date1,5)
kernel = np.ones((5,5),np.uint8)
date1 = cv2.erode(date1,kernel,iterations = 1)
show(date1)
getDigit(date1)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 7

# %%
show(date1)

# %%
# feature extract
im = cv2.imread('c1.png',0)

# im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)

im = cv2.resize(im, (2708, 1216), interpolation = cv2.INTER_AREA)

branch     = im[0:180, 900:2090]
date       = im[90:150, 2100:2650]
payee      = im[170:330, 200:2000]

amntWords1  = im[325:440,400:2630]
amntWords2  = im[440:540,100:1870]
amntDigit  = im[440:530,2150:2600]
account    = im[565:700, 210:1090]
signature  = im[600:900, 1850:2700]
chequeInfo = im[1090:1170, 720:990]
chequeType = im[0:110,0:250]
# chequeType = cv2.cvtColor(chequeType,cv2.COLOR_BGR2RGB)

# save image
amntWords1  = im[325:440,400:2630]
amntWords2  = im[440:540,100:1870]
cv2.imwrite("amntWords1.jpg",amntWords1)
cv2.imwrite("amntWords2.jpg",amntWords2)
# show(amntWords2)
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
text1 = pytesseract.image_to_string(Image.open('amntWords1.jpg'))
text2 = pytesseract.image_to_string(Image.open('amntWords2.jpg'))


# text1 = text1.strip() + " " + text2.strip()
# print(text1.strip())
# # show(amntWords)


# show(account)
cv2.imwrite("account.jpg",account)
pytesseract.image_to_string(Image.open('account.jpg')).replace(" ","")

# show(chequeInfo)
# cv2.imwrite("checkInfo.jpg",chequeInfo)
typeOfCheq = im[280:328, 2480:2750]
show(typeOfCheq)
cv2.imwrite("typeOfCheq.jpg",typeOfCheq)
pytesseract.image_to_string(Image.open('typeOfCheq.jpg'))
# Out:
# 'ORDER'

# %%
# show()
cv2.imwrite("branch.jpg",branch)
# Out:
# True

# %%
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter

# im = Image.open(name+".png") # the second one 
# im = im.filter(ImageFilter.MedianFilter())
# enhancer = ImageEnhance.Contrast(im)
# im = enhancer.enhance(2)
# im = im.convert('1')
# im.save('temp2.jpg')
text = pytesseract.image_to_string(Image.open('branch.jpg'))
print(text)
# plt.imshow(im)
# plt.show()
# Out:
# (“Til-I mm
# m PLAZA. FI-l-IIT. Wm
#
# "mu-min

# %%
# Import the modules
import cv2
from sklearn.externals import joblib
from skimage.feature import hog
import numpy as np
from imutils import contours
import matplotlib.pyplot as plt
# Load the classifier
clf = joblib.load("model/digits_cls.pkl")

# Read the input image 
im = cv2.imread("date.jpg")

# Convert to grayscale and apply Gaussian filtering
im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im_gray = cv2.GaussianBlur(im_gray, (5, 5), 0)

# Threshold the image
ret, im_th = cv2.threshold(im_gray, 90, 255, cv2.THRESH_BINARY_INV)

# Find contours in the image
im2, ctrs, hierarchy = cv2.findContours(im_th.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(im, ctrs, -1, (0,0,0), 3)
ctrs = contours.sort_contours(ctrs,method="left-to-right")[0]

# Get rectangles contains each contour

# for ctr in ctrs:
#     area = cv2.contourArea(ctr)
#     print(area)
ctrs = [x for x in ctrs if cv2.contourArea(x) > 100]
rects = [cv2.boundingRect(ctr) for ctr in ctrs]

# # For each rectangular region, calculate HOG features and predict
# # the digit using Linear SVM.
number = 0
for rect in rects[0:len(rects)]:
    # Draw the rectangles
    cv2.rectangle(im, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 0), 3)
    plt.imshow(im)
    plt.show()
    # Resize the image
    roi = im_th[rect[1]:rect[1] + rect[3], rect[0]:rect[0] + rect[2]]
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    
    roi = cv2.dilate(roi, (3, 3))
    plt.imshow(roi)
    plt.show()
    # Calculate the HOG features    
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), visualise=False)
    nbr = clf.predict(np.array([roi_hog_fd], 'float64'))
    number = int(nbr[0]) + number*10
    print(nbr[0])
print(number)
# Out:
# 2
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 5
# 2
# 0
# 2
# 0
# 7
# 7
# 25202077

# %%
from imutils import contours
import cv2
from sklearn.externals import joblib
from skimage.feature import hog
import numpy as np
from imutils import contours
import matplotlib.pyplot as plt

number = 0
clf = joblib.load("model/digits_cls.pkl")
def getDigit(img):
    im_gray = cv2.GaussianBlur(img, (5, 5), 0)

    # Threshold the image
    ret, im_th = cv2.threshold(im_gray, 90, 255, cv2.THRESH_BINARY_INV)
    im2, ctrs, hierarchy = cv2.findContours(img.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    ctrs = contours.sort_contours(ctrs,method="left-to-right")[0]
#     print(len(ctrs))
    rects = [cv2.boundingRect(ctr) for ctr in ctrs]
    number = 0
    for rect in rects[0:len(rects)]:
        # Draw the rectangles
        cv2.rectangle(img, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 0), 3)
#         show(img)
        # Resize the image
        roi = im_th[rect[1]:rect[1] + rect[3], rect[0]:rect[0] + rect[2]]
        roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)

        roi = cv2.dilate(roi, (3, 3))
#         show(roi)
        # Calculate the HOG features    
        roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), visualise=False)
        nbr = clf.predict(np.array([roi_hog_fd], 'float64'))
        number = int(nbr[0]) + number*10
        
    return number

# %%
def show(img):
    import matplotlib.pyplot as plt
    plt.imshow(img, cmap='gray')
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
def getText(name):
    import pytesseract
    from PIL import Image, ImageEnhance, ImageFilter
    text = pytesseract.image_to_string(Image.open(name))
    return text

# %%
import cv2
# processing of image
im = cv2.imread('cheque.jpg',0)
h, w = im.shape
date = im[int(h*0.07):int(h*0.125), int(w*0.773):w-(int(h*0.05))]

h, w = date.shape

show(date)
part = int(164/8)
date1 = date[0:h, 0:part]
date2 = date[0:h, part:2*part]
date3 = date[0:h, 2*part+5:3*part]

show(date3)
getDigit(date3)
# date2 = imgray[85:140, 2175:2230]
# date3 = imgray[85:140, 2245:2300]
# date4 = imgray[85:140, 2310:2370]
# date5 = imgray[85:140, 2380:2435]
# date6 = imgray[85:140, 2445:2505]
# date7 = imgray[85:140, 2515:2575]
# date8 = imgray[85:140, 2590:2650]

# # kernel = np.ones((5,5),np.uint8)
# # date1 = cv2.morphologyEx(date1, cv2.MORPH_GRADIENT, kernel)

# date = str(getDigit(date1))+""+str(getDigit(date2))+"/"+str(getDigit(date3))+""+str(getDigit(date4))+"/"+str(getDigit(date5))+""+str(getDigit(date6))+str(getDigit(date7))+""+str(getDigit(date8))
# print(date)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 7

# %%
# 3. extract payee
payee = imgray[170:330, 200:2000]
show(payee)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Load the data, converters convert the letter to a number
data= np.loadtxt('letter-recognition.data', dtype= 'float32', delimiter = ',',
                    converters= {0: lambda ch: ord(ch)-ord('A')})
# split the data to two, 10000 each for train and test
train, test = np.vsplit(data,2)
# split trainData and testData to features and responses
responses, trainData = np.hsplit(train,[1])
labels, testData = np.hsplit(test,[1])
# Initiate the kNN, classify, measure accuracy.
knn = cv2.ml.KNearest_create()
knn.train(trainData, cv2.ml.ROW_SAMPLE, responses)
ret, result, neighbours, dist = knn.findNearest(testData, k=5)
correct = np.count_nonzero(result == labels)
accuracy = correct*100.0/10000
print( accuracy )
# Out:
# 93.06

# %%
# type of cheque
typeOfCheq = imgray[220:320, 2390:2670]
show(typeOfCheq)
cv2.imwrite("typeOfCheq.jpg",typeOfCheq)
chequeType = getText("typeOfCheq.jpg")
print(chequeType)
# Out:
# OR ORDER

# %%
def getAmountDigit(img,name):
    number = 0
    im_gray = cv2.GaussianBlur(img, (5, 5), 0)

    # Threshold the image
    ret, im_th = cv2.threshold(im_gray, 90, 255, cv2.THRESH_BINARY_INV)
    im2, ctrs, hierarchy = cv2.findContours(im_th, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    temp = cv2.imread(name)
    cv2.drawContours(temp,ctrs,-1,(255,0,0),3)
#     show(temp)
    ctrs = contours.sort_contours(ctrs,method="left-to-right")[0]
#     print(len(ctrs))
#     for ctr in ctrs:
#         print(cv2.contourArea(ctr))
    ctrs = [x for x in ctrs if cv2.contourArea(x) > 200]
    rects = [cv2.boundingRect(ctr) for ctr in ctrs]
    number = 0
#     print(rects)
    for rect in rects[0:len(rects)]:
        # Draw the rectangles
        cv2.rectangle(temp, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (0, 255, 0), 3)
        
#         show(temp)
        # Resize the image
        roi = im_th[rect[1]:rect[1] + rect[3], rect[0]-10:5+rect[0] + rect[2]]
#         show(roi)
        roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
# show(roi)
        roi = cv2.dilate(roi, (3, 3))
#         show(roi)
        # Calculate the HOG features    
        roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), visualise=False)
        nbr = clf.predict(np.array([roi_hog_fd], 'float64'))
        number = int(nbr[0]) + number*10
        
    return number

# %%
amntDigit  = imgray[445:525,2150:2590]
kernel = np.ones((5,5),np.uint8)
amntDigit = cv2.erode(amntDigit,kernel,iterations = 1)
amntDigit = cv2.morphologyEx(amntDigit, cv2.MORPH_CLOSE, kernel)
cv2.imwrite("amntDigit.jpg",amntDigit)
amntDigit = cv2.imread("amntDigit.jpg",0)
getAmountDigit(amntDigit,"amntDigit.jpg")
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 10000

# %%
account    = imgray[565:700, 210:1090]
show(account)
cv2.imwrite("account.jpg",account)
account = getText("account.jpg")

# %%
signature  = imgray[600:900, 1850:2700]
show(signature)

# %%
chequeInfo = imgray[1090:1170,715:985]
kernel = np.ones((5,5),np.uint8)
chequeInfo = cv2.erode(chequeInfo,kernel,iterations = 1)
chequeInfo = cv2.morphologyEx(chequeInfo, cv2.MORPH_CLOSE, kernel)
cv2.imwrite("chequeInfo.jpg",chequeInfo)
chequeInfo = cv2.imread("chequeInfo.jpg",0)
show(chequeInfo)
cv2.imwrite("chequeInfo.jpg",chequeInfo)
# Out:
# True

# %%
# # amount in words
amntWords1  = im[325:440,400:2630]
amntWords2  = im[440:540,100:1870]
cv2.imwrite("temp/amntWords1.jpg",amntWords1)
cv2.imwrite("temp/amntWords2.jpg",amntWords2)

# following are feature calls for functions
# Out:
# True

# %%
def signature_match(path1, path2):


    # import the necessary packages
    import numpy as np
    import cv2
    import sys
    from matplotlib import pyplot as plt


    
    # In[41]:


    # open images
    im1 = cv2.imread(path1, 0)
    im2 = cv2.imread(path2, 0)

   
    # resize the images
    img1 = cv2.resize(im1, (1300, 500), interpolation = cv2.INTER_AREA)
    img2 = cv2.resize(im2, (1300, 500), interpolation = cv2.INTER_AREA)
    
    
    # In[42]:


    # Initiate SIFT detector
    orb = cv2.ORB_create()


    # In[43]:


#     # find the keypoints and descriptors with SIFT
    # find the keypoints with ORB
    kp1 = orb.detect(img1,None)
    # compute the descriptors with ORB
    kp1, des1 = orb.compute(img1, kp1)
    
    kp2 = orb.detect(img2,None)
    # compute the descriptors with ORB
    kp2, des2 = orb.compute(img2, kp2)
    
    # create BFMatcher object
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

    # Match descriptors.
    matches= bf.match(des1,des2)

    # Sort them in the order of their distance.
    matches = sorted(matches, key = lambda x:x.distance)
    match_percent = (len(matches)*100)/len(des1)
    # print "Match Percentage = ",match_percent
    
    
    return match_percent

# %%
signature_match("33073979030-Sign.png","signature.jpg")
# Out:
# 47.6

# %%
# imports
import cv2
from imutils import contours
import cv2
from sklearn.externals import joblib
from skimage.feature import hog
import numpy as np
from imutils import contours
import matplotlib.pyplot as plt
import numpy as np
import cv2
import sys
from matplotlib import pyplot as plt



# utility functions
def verifySign(path1, path2):

    im1 = cv2.imread(path1, 0)
    im2 = cv2.imread(path2, 0)

   
    # resize the images
    img1 = cv2.resize(im1, (1300, 500), interpolation = cv2.INTER_AREA)
    img2 = cv2.resize(im2, (1300, 500), interpolation = cv2.INTER_AREA)
    
    
    
    # Initiate SIFT detector
    orb = cv2.ORB_create()

    # find the keypoints with ORB
    kp1 = orb.detect(img1,None)
    # compute the descriptors with ORB
    kp1, des1 = orb.compute(img1, kp1)
    
    kp2 = orb.detect(img2,None)
    # compute the descriptors with ORB
    kp2, des2 = orb.compute(img2, kp2)
    
    # create BFMatcher object
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

    # Match descriptors.
    matches= bf.match(des1,des2)

    # Sort them in the order of their distance.
    matches = sorted(matches, key = lambda x:x.distance)
    match_percent = (len(matches)*100)/len(des1)
    return match_percent
# -------------------------------------------------------------------------------------

def getAmountDigit(img,name):
    number = 0
    im_gray = cv2.GaussianBlur(img, (5, 5), 0)
    # Threshold the image
    ret, im_th = cv2.threshold(im_gray, 90, 255, cv2.THRESH_BINARY_INV)
    im2, ctrs, hierarchy = cv2.findContours(im_th, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    temp = cv2.imread(name)
    cv2.drawContours(temp,ctrs,-1,(255,0,0),3)
    ctrs = contours.sort_contours(ctrs,method="left-to-right")[0]

    # for non digits filter the contours
    ctrs = [x for x in ctrs if cv2.contourArea(x) > 200]
    
    rects = [cv2.boundingRect(ctr) for ctr in ctrs]
    
    number = 0
    for rect in rects[0:len(rects)]:
        # Draw the rectangles
        cv2.rectangle(temp, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (0, 255, 0), 3)
        # Resize the image
        roi = im_th[rect[1]:rect[1] + rect[3], rect[0]-10:5+rect[0] + rect[2]]
        roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
        roi = cv2.dilate(roi, (3, 3))

        # Calculate the HOG features    
        roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), visualise=False)
        nbr = clf.predict(np.array([roi_hog_fd], 'float64'))
        number = int(nbr[0]) + number*10
        
    return number

# -------------------------------------------------------------------------------------
def getDigit(img):

    number = 0
    clf = joblib.load("model/digits_cls.pkl")
    im_gray = cv2.GaussianBlur(img, (5, 5), 0)

    # Threshold the image
    ret, im_th = cv2.threshold(im_gray, 90, 255, cv2.THRESH_BINARY_INV)
    im2, ctrs, hierarchy = cv2.findContours(img.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    ctrs = contours.sort_contours(ctrs,method="left-to-right")[0]
    rects = [cv2.boundingRect(ctr) for ctr in ctrs]
    number = 0

    for rect in rects[0:len(rects)]:
        # Draw the rectangles
        cv2.rectangle(img, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 0), 3)
        # Resize the image
        roi = im_th[rect[1]:rect[1] + rect[3], rect[0]:rect[0] + rect[2]]
        roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
        roi = cv2.dilate(roi, (3, 3))
        # Calculate the HOG features    
        roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), visualise=False)
        nbr = clf.predict(np.array([roi_hog_fd], 'float64'))
        number = int(nbr[0]) + number*10
        
    return number
# -------------------------------------------------------------------------------------
def show(img):
    import matplotlib.pyplot as plt
    plt.imshow(img, cmap='gray')
    plt.xticks([]), plt.yticks([])
    plt.show()
# -------------------------------------------------------------------------------------
def getText(name):
    import pytesseract
    from PIL import Image, ImageEnhance, ImageFilter
    text = pytesseract.image_to_string(Image.open(name))
    return text
# -------------------------------------------------------------------------------------
# processing of image
imgName = "c1.jpg"
im = cv2.imread(imgName)
im = cv2.resize(im, (2708, 1216), interpolation = cv2.INTER_AREA)
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
cv2.imwrite("cheque.jpg",imgray)

# ---------------------------------------------------------------------
# 1. extract features from the image
# ---------------------------------------------------------------------
branch     = imgray[0:180, 900:2090]
cv2.imwrite("branch.jpg",branch)

branchName = "Not Found"
try:
    branchName = getText("branch.jpg").replace('\n','').replace('\'','')
except:
    print("branch not found")


# ---------------------------------------------------------------------
# 2. extract date from the image
# ---------------------------------------------------------------------
date = imgray[85:145, 2110:2650]
date1 = date[5:150,0:60]
date2 = date[5:150, 70:130]
date3 = date[5:150, 140:195]
date4 = date[5:150, 205:265]
date5 = date[0:150, 275:330]
date6 = date[0:150, 340:400]
date7 = date[0:150, 410:470]
date8 = date[0:150, 480:550]


# try:
#     date = str(getDigit(date1))+""+str(getDigit(date2))+"/"+str(getDigit(date3))+""+str(getDigit(date4))+"/"+str(getDigit(date5))+""+str(getDigit(date6))+str(getDigit(date7))+""+str(getDigit(date8))
# except:
#     date = "Not Found"
    
# print(date)
# show(date)
# ---------------------------------------------------------------------
# 3. extract payee
# ---------------------------------------------------------------------

# %%
date8 =date[0:150, 410:470]
show(date8)
getDigit(date8)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 7

# %%
date2 = date[5:150, 65:120]
show(date2)
getDigit(date1)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 2

# %%
date3 = date[5:150, 130:190]
show(date3)
getDigit(date3)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 1

# %%
date4 = date[5:150, 200:260]
show(date4)
getDigit(date4)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 1

# %%
date5 = date[0:150, 270:325]
show(date5)
getDigit(date5)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 2

# %%
date6 = date[5:150, 335:390]
show(date6)
getDigit(date6)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 0

# %%
date7 = date[5:150, 405:460]
show(date7)
getDigit(date7)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 1

# %%
date8 = date[5:150, 475:560]
show(date8)
getDigit(date8)
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 7

# %%
payee = imgray[170:320, 200:2000]
kernel = np.ones((5,5),np.uint8)
# payee = cv2.dilate(payee,kernel,iterations = 1)
cv2.imwrite("payee.jpg",payee)
show(payee)

text = getText("payee.jpg")
print(text)
# Out:
# TANYA AHUJA

# %%
typeOfCheq = imgray[280:320, 2480:2750]
show(typeOfCheq)
cv2.imwrite("typeOfCheq.jpg",typeOfCheq)
chequeType = getText("typeOfCheq.jpg")
# Out:
#  asdfasdORDER

# %%
amntDigit  = imgray[445:525,2150:2590]
kernel = np.ones((5,5),np.uint8)
amntDigit = cv2.erode(amntDigit,kernel,iterations = 1)
amntDigit = cv2.morphologyEx(amntDigit, cv2.MORPH_CLOSE, kernel)
cv2.imwrite("amntDigit.jpg",amntDigit)
getAmountDigit(amntDigit,"amntDigit.jpg")
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 10000

# %%
account    = imgray[600:690, 220:1090]
show(account)
kernel = np.ones((5,5),np.uint8)
account = cv2.erode(account,kernel,iterations = 1)
account = cv2.morphologyEx(account, cv2.MORPH_CLOSE, kernel)
show(account)
cv2.imwrite("account.jpg",account)
# getAmountDigit(account,"account.jpg")
# Out:
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 11718871181

# %%
def getText(name):
    import pytesseract
    from PIL import Image, ImageEnhance, ImageFilter
    text = pytesseract.image_to_string(Image.open(name))
    return text

# %%
def text2int(textnum, numwords={}):
    if not numwords:
        units = [
        "zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen",
        ]

        tens = ["", "", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]

        scales = ["hundred", "thousand", "million", "billion", "trillion"]

        numwords["and"] = (1, 0)
        for idx, word in enumerate(units):    numwords[word] = (1, idx)
        for idx, word in enumerate(tens):     numwords[word] = (1, idx * 10)
        for idx, word in enumerate(scales):   numwords[word] = (10 ** (idx * 3 or 2), 0)

    current = result = 0
    for word in textnum.split():
        if word not in numwords:
            raise Exception("Illegal word: " + word)

        scale, increment = numwords[word]
        current = current * scale + increment
        if scale > 100:
            result += current
            current = 0

    return result + current

# %%
int(text2int(str.lower(getText("1.png"))))
# Out:
# 5200

# %%
def getDigit(img):

    number = 0
    clf = joblib.load("model/digits_cls.pkl")
    im_gray = cv2.GaussianBlur(img, (5, 5), 0)

    # Threshold the image
    ret, im_th = cv2.threshold(im_gray, 90, 255, cv2.THRESH_BINARY_INV)
    im2, ctrs, hierarchy = cv2.findContours(img.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    ctrs = contours.sort_contours(ctrs,method="left-to-right")[0]
    rects = [cv2.boundingRect(ctr) for ctr in ctrs]
    number = 0

    for rect in rects[0:len(rects)]:
        # Draw the rectangles
        cv2.rectangle(img, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 0), 3)
        # Resize the image
        roi = im_th[rect[1]:rect[1] + rect[3], rect[0]:rect[0] + rect[2]]
        roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
        roi = cv2.dilate(roi, (3, 3))
        # Calculate the HOG features    
        roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), visualise=False)
        nbr = clf.predict(np.array([roi_hog_fd], 'float64'))
        number = int(nbr[0]) + number*10
        
    return number

# %%
date = imgray[95:145, 2080:2620]
show(date)
cv2.imwrite("date.jpg",date)
date = cv2.imread("date.jpg",0)
print(date.shape)
date1 = date[0:85, 0:50]
show(date1)
# date2 = imgray[85:140, 2175:2230]
# date3 = imgray[85:140, 2245:2300]
# date4 = imgray[85:140, 2310:2370]
# date5 = imgray[85:140, 2380:2435]
# date6 = imgray[85:140, 2445:2505]
# date7 = imgray[85:140, 2515:2575]
# date8 = imgray[85:140, 2590:2650]

# try:
#     date = str(getDigit(date1))+""+str(getDigit(date2))+"/"+str(getDigit(date3))+""+str(getDigit(date4))+"/"+str(getDigit(date5))+""+str(getDigit(date6))+str(getDigit(date7))+""+str(getDigit(date8))
# except:
#     date = "Not Found"

# show(date)
str(getDigit(date1))
# Out:
# (50, 540)
# /home/amit/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# '8'

# %%
# ---------------------------------------------------------------------
# 4. type of cheque
# ---------------------------------------------------------------------
typeOfCheq = imgray[280:328, 2480:2750]
cv2.imwrite("typeOfCheq.jpg",typeOfCheq)
chequeType = getText("typeOfCheq.jpg")


# ---------------------------------------------------------------------
# 5. amount in digits
# ---------------------------------------------------------------------
amntDigit  = imgray[445:525,2150:2590]
kernel = np.ones((5,5),np.uint8)
amntDigit = cv2.erode(amntDigit,kernel,iterations = 1)
amntDigit = cv2.morphologyEx(amntDigit, cv2.MORPH_CLOSE, kernel)
cv2.imwrite("amntDigit.jpg",amntDigit)
amntDigit = cv2.imread("amntDigit.jpg",0)
amntDigit = "not found"

try:
    amntDigit = getAmountDigit(amntDigit,"amntDigit.jpg")
except:
    amntDigit = "not found"


# ---------------------------------------------------------------------
# 6. Account number
# ---------------------------------------------------------------------
account    = imgray[565:700, 210:1090]
# show(account)
cv2.imwrite("account.jpg",account)

account = "not found"
try:
    account = getText("account.jpg")
except:
    account = "not found"

# print(account)
# ---------------------------------------------------------------------
# 7. Signature
# ---------------------------------------------------------------------
signature  = imgray[600:900, 1850:2700]
cv2.imwrite("signature.jpg",signature)
# verify the signature with respect to original one
sigFlag = False
imName = str(account)+"-Sign.png"
try:
    if verifySign(imName,"signature.jpg") >= 47:
        sigFlag = True
except:
    print("signature verification went wrong")
    

# ---------------------------------------------------------------------
# 8. ChequeInfo
# ---------------------------------------------------------------------
chequeInfo = imgray[1090:1170,715:985]
kernel = np.ones((5,5),np.uint8)
chequeInfo = cv2.erode(chequeInfo,kernel,iterations = 1)
chequeInfo = cv2.morphologyEx(chequeInfo, cv2.MORPH_CLOSE, kernel)
cv2.imwrite("chequeInfo.jpg",chequeInfo)
chequeInfo = "chequeInfo.jpg"

# ---------------------------------------------------------------------
# 9. amount in words
# ---------------------------------------------------------------------

amntWords1  = im[325:440,400:2630]
amntWords2  = im[440:540,100:1870]
cv2.imwrite("amntWords1.jpg",amntWords1)
cv2.imwrite("amntWords2.jpg",amntWords2)
# show(amntWords2)
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
text1 = pytesseract.image_to_string(Image.open('amntWords1.jpg')).strip()
text2 = pytesseract.image_to_string(Image.open('amntWords2.jpg')).strip()
amntWords = (text1 + " " + text2).strip()

import json 
chequeData = {"date":date,"payeeImg":payeeImg,"chequeType":chequeType,"amntDigit":amntDigit,"account":account,"signature":sigFlag,"chequeInfo":chequeInfo,"amntWords":amntWords}
json_data = json.dumps(chequeData)
print(json_data)

show("chequeInfo.jpg")
